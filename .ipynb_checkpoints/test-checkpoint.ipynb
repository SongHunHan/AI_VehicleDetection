# %%
from glob import glob

# %%
test_img = glob('/workspace/ssddata/yolov5_car_dataset/test_dataset/*.jpg')
len(test_img)
# Out:
# 3

# %%
test_img = test_img[2]

# %%
cd yolov5
# Out:
# /workspace/Docker/yolov5_car/yolov5

# %%
# !python detect.py --weight /workspace/Docker/yolov5_car/yolov5/runs/train/yolov5_car/weights/best.pt --img 416 --conf 0.5 --source "{test_img}"
# Out:
# detect: weights=['/workspace/Docker/yolov5_car/yolov5/runs/train/yolov5_car/weights/best.pt'], source=/workspace/ssddata/yolov5_car_dataset/test_dataset/50569_61683_1649.jpg, imgsz=416, conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-291-gb7e985e torch 1.7.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46654416 parameters, 0 gradients, 114.3 GFLOPs
# image 1/1 /workspace/ssddata/yolov5_car_dataset/test_dataset/50569_61683_1649.jpg: 256x416 3 cars, Done. (0.020s)
# Results saved to runs/detect/exp28
# Done. (0.042s)

# %%
cd yolov5
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /workspace/Docker/yolov5_car/yolov5

# %%
test_v = glob('/workspace/ssddata/yolov5_car_dataset/test_dataset/*.mp4')
test_v
# Out:
# ['/workspace/ssddata/yolov5_car_dataset/test_dataset/test_v.mp4']

# %%
# !python detect.py --weight /workspace/Docker/yolov5_car/yolov5/runs/train/yolov5_car/weights/best.pt --source '/workspace/ssddata/yolov5_car_dataset/test_dataset/test_v.mp4'
# Out:
# detect: weights=['/workspace/Docker/yolov5_car/yolov5/runs/train/yolov5_car/weights/best.pt'], source=/workspace/ssddata/yolov5_car_dataset/test_dataset/test_v.mp4, imgsz=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-291-gb7e985e torch 1.7.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46654416 parameters, 0 gradients, 114.3 GFLOPs
# video 1/1 (1/1170) /workspace/ssddata/yolov5_car_dataset/test_dataset/test_v.mp4: 384x640 3 cars, 3 pedestrians, Done. (0.014s)
# video 1/1 (2/1170) /workspace/ssddata/yolov5_car_dataset/test_dataset/test_v.mp4: 384x640 3 cars, 3 pedestrians, Done. (0.010s)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#batch prediction

# %%
batch_images = glob('/workspace/ssddata/yolov5_car_dataset/test_dataset/*.jpg')
len(batch_images)
# Out:
# 3

# %%
fig=plt.figure(figsize=(20, 28))
columns = 3
rows = 5
for i in range(1, columns*rows +1):
    img = np.random.choice(batch_images)
    img = plt.imread(img)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
# !python detect.py --source '/workspace/Docker/yolov5_car/yolov5/data/images/' --weights '/workspace/Docker/yolov5_car/yolov5/runs/train/yolov5_car/weights/best.pt'
# Out:
# detect: weights=['/workspace/Docker/yolov5_car/yolov5/runs/train/yolov5_car/weights/best.pt'], source=/workspace/Docker/yolov5_car/yolov5/data/images/, imgsz=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-291-gb7e985e torch 1.7.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46654416 parameters, 0 gradients, 114.3 GFLOPs
# image 1/2 /workspace/Docker/yolov5_car/yolov5/data/images/bus.jpg: 640x480 8 pedestrians, Done. (0.017s)
# image 2/2 /workspace/Docker/yolov5_car/yolov5/data/images/zidane.jpg: 384x640 Done. (0.014s)
# Results saved to runs/detect/exp21
# Done. (0.093s)

# %%
# !python detect2.py --weight /workspace/Docker/yolov5_car/yolov5/runs/train/yolov5_car/weights/best.pt --img 416 --conf 0.5 --source "{test_img}"
# Out:
# detect: weights=['/workspace/Docker/yolov5_car/yolov5/runs/train/yolov5_car/weights/best.pt'], source=/workspace/ssddata/yolov5_car_dataset/test_dataset/50569_61683_1649.jpg, imgsz=416, conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-291-gb7e985e torch 1.7.1 CUDA:0 (NVIDIA GeForce RTX 3090, 24265.3125MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46654416 parameters, 0 gradients, 114.3 GFLOPs
# image 1/1 /workspace/ssddata/yolov5_car_dataset/test_dataset/50569_61683_1649.jpg: tensor([[[[0.44706, 0.44706, 0.44706,  ..., 0.44706, 0.44706, 0.44706],
#           [0.44706, 0.44706, 0.44706,  ..., 0.44706, 0.44706, 0.44706],
# ...
